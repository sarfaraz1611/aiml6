# %%
import numpy as np
import pandas as pd
import pandas as pd

# %%
df=pd.read_csv('a8.csv')

# %%
df
# Out:
#      Outlook Temperature Humidity     Wind Play
# 0      Sunny         Hot     High     Weak   No
# 1      Sunny         Hot     High  Srtrong   No
# 2   Overcast         Hot     High     Weak  Yes
# 3       Rain        Mild     High     Weak  Yes
# 4       Rain        Cool   Normal     Weak  Yes
# 5       Rain        Cool   Normal  Srtrong   No
# 6   Overcast        Cool   Normal  Srtrong  Yes
# 7      Sunny        Mild     High     Weak   No
# 8      Sunny        Cool   Normal     Weak  Yes
# 9       Rain        Mild   Normal     Weak  Yes
# 10     Sunny        Mild   Normal  Srtrong  Yes
# 11  Overcast        Mild     High  Srtrong  Yes
# 12  Overcast         Hot   Normal     Weak  Yes
# 13      rain        Mild     High  Srtrong   No
